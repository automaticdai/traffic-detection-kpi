# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.94-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.94-py3-none-any.whl (949 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 15.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.94 ultralytics-thop-2.0.14

# %%
import cv2

from ultralytics import solutions

def count_specific_classes(video_path, output_video_path, model_path, classes_to_count):
    """Count specific classes of objects in a video."""
    cap = cv2.VideoCapture(video_path)
    assert cap.isOpened(), "Error reading video file"
    w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
    video_writer = cv2.VideoWriter(output_video_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

    line_points = [(300, 570), (900, 550), (750, 150), (500, 150)]
    counter = solutions.ObjectCounter(show=True, region=line_points, model=model_path, classes=classes_to_count, tracker="bytetrack.yaml")

    while cap.isOpened():
        success, im0 = cap.read()
        if not success:
            print("Video frame is empty or processing is complete.")
            break
        results = counter(im0)
        #cv2_imshow(results)
        video_writer.write(results.plot_im)

    cap.release()
    video_writer.release()
    cv2.destroyAllWindows()


count_specific_classes("../trafficData/four lanes.mp4", "trackzone.avi", "yolo11n.pt", [0, 2, 3, 5, 7])
# Out:
# Streaming output truncated to the last 5000 lines.
# Speed: 3.3ms preprocess, 134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 115.0ms
# Speed: 2.6ms preprocess, 115.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 124.7ms
# Speed: 2.7ms preprocess, 124.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 127.4ms
# Speed: 3.4ms preprocess, 127.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 117.6ms
# Speed: 2.5ms preprocess, 117.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 118.2ms
# Speed: 3.9ms preprocess, 118.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 118.8ms
# Speed: 2.5ms preprocess, 118.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 136.6ms
# Speed: 5.0ms preprocess, 136.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 116.3ms
# Speed: 2.8ms preprocess, 116.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 117.7ms
# Speed: 2.8ms preprocess, 117.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 117.2ms
# Speed: 2.7ms preprocess, 117.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 10 cars, 118.0ms
# Speed: 2.8ms preprocess, 118.0ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 9 cars, 1 truck, 125.5ms
# Speed: 2.5ms preprocess, 125.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 9 cars, 1 truck, 127.9ms
# Speed: 2.7ms preprocess, 127.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 11 cars, 1 truck, 139.9ms
# Speed: 6.8ms preprocess, 139.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 136.1ms
# Speed: 3.2ms preprocess, 136.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 132.7ms
# Speed: 4.6ms preprocess, 132.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 134.4ms
# Speed: 3.1ms preprocess, 134.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 bus, 141.2ms
# Speed: 3.2ms preprocess, 141.2ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 142.0ms
# Speed: 4.0ms preprocess, 142.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 182.4ms
# Speed: 3.6ms preprocess, 182.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 133.1ms
# Speed: 5.8ms preprocess, 133.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 132.2ms
# Speed: 3.2ms preprocess, 132.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 127.8ms
# Speed: 3.1ms preprocess, 127.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 130.3ms
# Speed: 3.7ms preprocess, 130.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 138.0ms
# Speed: 3.7ms preprocess, 138.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 151.4ms
# Speed: 3.1ms preprocess, 151.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 131.4ms
# Speed: 4.8ms preprocess, 131.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 132.5ms
# Speed: 4.0ms preprocess, 132.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 131.6ms
# Speed: 3.4ms preprocess, 131.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 138.4ms
# Speed: 3.4ms preprocess, 138.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 131.9ms
# Speed: 3.8ms preprocess, 131.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 142.0ms
# Speed: 3.1ms preprocess, 142.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 bus, 136.4ms
# Speed: 3.5ms preprocess, 136.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 126.3ms
# Speed: 3.2ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 130.4ms
# Speed: 4.3ms preprocess, 130.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 1 truck, 129.5ms
# Speed: 3.5ms preprocess, 129.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=5, classwise_count={'car': {'IN': 2, 'OUT': 5}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 138.4ms
# Speed: 3.4ms preprocess, 138.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=6, classwise_count={'car': {'IN': 2, 'OUT': 6}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 14 cars, 151.1ms
# Speed: 3.4ms preprocess, 151.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=2, out_count=6, classwise_count={'car': {'IN': 2, 'OUT': 6}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 1 truck, 128.5ms
# Speed: 3.4ms preprocess, 128.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=6, classwise_count={'car': {'IN': 3, 'OUT': 6}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 1 truck, 128.6ms
# Speed: 3.1ms preprocess, 128.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=6, classwise_count={'car': {'IN': 3, 'OUT': 6}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 14 cars, 1 truck, 131.4ms
# Speed: 3.9ms preprocess, 131.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 13 cars, 1 truck, 131.7ms
# Speed: 4.6ms preprocess, 131.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 124.1ms
# Speed: 3.7ms preprocess, 124.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 135.4ms
# Speed: 3.2ms preprocess, 135.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 1 truck, 118.7ms
# Speed: 2.7ms preprocess, 118.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 1 truck, 116.1ms
# Speed: 2.7ms preprocess, 116.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 1 truck, 115.2ms
# Speed: 2.8ms preprocess, 115.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=3, out_count=7, classwise_count={'car': {'IN': 3, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 14 cars, 1 truck, 125.1ms
# Speed: 2.8ms preprocess, 125.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 15 cars, 122.8ms
# Speed: 2.9ms preprocess, 122.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 15 cars, 132.3ms
# Speed: 2.7ms preprocess, 132.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 14 cars, 142.6ms
# Speed: 3.2ms preprocess, 142.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 131.7ms
# Speed: 3.6ms preprocess, 131.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 132.9ms
# Speed: 4.7ms preprocess, 132.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=7, classwise_count={'car': {'IN': 4, 'OUT': 7}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 138.0ms
# Speed: 3.2ms preprocess, 138.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 144.4ms
# Speed: 3.4ms preprocess, 144.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 152.0ms
# Speed: 3.3ms preprocess, 152.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 223.0ms
# Speed: 2.8ms preprocess, 223.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 206.8ms
# Speed: 2.9ms preprocess, 206.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 11 cars, 1 truck, 200.0ms
# Speed: 6.0ms preprocess, 200.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 11 cars, 1 truck, 217.8ms
# Speed: 2.7ms preprocess, 217.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 12 cars, 1 truck, 236.9ms
# Speed: 3.5ms preprocess, 236.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 204.7ms
# Speed: 3.3ms preprocess, 204.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 197.2ms
# Speed: 3.2ms preprocess, 197.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 199.3ms
# Speed: 3.3ms preprocess, 199.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 11 cars, 2 trucks, 195.7ms
# Speed: 3.9ms preprocess, 195.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 200.9ms
# Speed: 2.9ms preprocess, 200.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 184.3ms
# Speed: 2.9ms preprocess, 184.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 2 trucks, 188.6ms
# Speed: 2.9ms preprocess, 188.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 12 cars, 2 trucks, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 1 truck, 194.9ms
# Speed: 3.8ms preprocess, 194.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 12 cars, 2 trucks, 207.7ms
# Speed: 3.0ms preprocess, 207.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 218.5ms
# Speed: 5.4ms preprocess, 218.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 13 cars, 1 truck, 211.4ms
# Speed: 3.8ms preprocess, 211.4ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 143.8ms
# Speed: 5.0ms preprocess, 143.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 137.8ms
# Speed: 3.3ms preprocess, 137.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars, 138.0ms
# Speed: 3.7ms preprocess, 138.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=4, out_count=8, classwise_count={'car': {'IN': 4, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 14 cars,
9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 226.9ms
# Speed: 3.5ms preprocess, 226.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 216.9ms
# Speed: 3.3ms preprocess, 216.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 186.3ms
# Speed: 3.1ms preprocess, 186.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 213.2ms
# Speed: 3.5ms preprocess, 213.2ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 232.9ms
# Speed: 2.8ms preprocess, 232.9ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 198.6ms
# Speed: 4.0ms preprocess, 198.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 179.0ms
# Speed: 3.1ms preprocess, 179.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 177.5ms
# Speed: 3.3ms preprocess, 177.5ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 185.5ms
# Speed: 2.7ms preprocess, 185.5ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 196.4ms
# Speed: 3.0ms preprocess, 196.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 202.9ms
# Speed: 2.9ms preprocess, 202.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 180.7ms
# Speed: 2.9ms preprocess, 180.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 188.1ms
# Speed: 3.1ms preprocess, 188.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 189.5ms
# Speed: 2.8ms preprocess, 189.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 212.6ms
# Speed: 5.2ms preprocess, 212.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 189.2ms
# Speed: 2.9ms preprocess, 189.2ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 191.1ms
# Speed: 2.9ms preprocess, 191.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 185.8ms
# Speed: 5.8ms preprocess, 185.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 185.2ms
# Speed: 3.3ms preprocess, 185.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 117.4ms
# Speed: 2.6ms preprocess, 117.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 12 cars, 1 truck, 124.8ms
# Speed: 4.7ms preprocess, 124.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 126.4ms
# Speed: 3.0ms preprocess, 126.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 124.7ms
# Speed: 2.9ms preprocess, 124.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 125.4ms
# Speed: 3.1ms preprocess, 125.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 126.8ms
# Speed: 3.4ms preprocess, 126.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 124.3ms
# Speed: 2.7ms preprocess, 124.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 131.0ms
# Speed: 2.7ms preprocess, 131.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 121.4ms
# Speed: 3.1ms preprocess, 121.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=5, out_count=8, classwise_count={'car': {'IN': 5, 'OUT': 8}, 'truck': {'IN': 0, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 13 cars, 124.6ms
# Speed: 2.8ms preprocess, 124.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# ...
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 3 persons, 9 cars, 134.3ms
# Speed: 3.5ms preprocess, 134.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 4 persons, 11 cars, 134.9ms
# Speed: 3.8ms preprocess, 134.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 4 persons, 11 cars, 134.8ms
# Speed: 4.2ms preprocess, 134.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 4 persons, 11 cars, 132.8ms
# Speed: 3.4ms preprocess, 132.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 4 persons, 11 cars, 149.2ms
# Speed: 3.2ms preprocess, 149.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 320x640 3 persons, 11 cars, 160.9ms
# Speed: 3.6ms preprocess, 160.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 3 persons, 10 cars, 139.0ms
# Speed: 3.6ms preprocess, 139.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 320x640 3 persons, 11 cars, 128.3ms
# Speed: 4.2ms preprocess, 128.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 320x640 2 persons, 10 cars, 143.5ms
# Speed: 3.9ms preprocess, 143.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 2 persons, 10 cars, 146.6ms
# Speed: 4.1ms preprocess, 146.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 2 persons, 10 cars, 135.2ms
# Speed: 3.2ms preprocess, 135.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 2 persons, 9 cars, 146.6ms
# Speed: 2.6ms preprocess, 146.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 125.0ms
# Speed: 3.6ms preprocess, 125.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 9 cars, 132.3ms
# Speed: 3.5ms preprocess, 132.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 9 cars, 129.9ms
# Speed: 3.1ms preprocess, 129.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 200.0ms
# Speed: 2.8ms preprocess, 200.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 7 cars, 1 bus, 199.1ms
# Speed: 2.8ms preprocess, 199.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 2 persons, 8 cars, 189.1ms
# Speed: 4.4ms preprocess, 189.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 2 persons, 8 cars, 177.6ms
# Speed: 2.9ms preprocess, 177.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 2 persons, 7 cars, 1 truck, 193.0ms
# Speed: 2.9ms preprocess, 193.0ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 199.6ms
# Speed: 3.1ms preprocess, 199.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 201.9ms
# Speed: 2.8ms preprocess, 201.9ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 199.3ms
# Speed: 3.0ms preprocess, 199.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 192.8ms
# Speed: 3.2ms preprocess, 192.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 221.9ms
# Speed: 6.4ms preprocess, 221.9ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 219.6ms
# Speed: 3.6ms preprocess, 219.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 208.7ms
# Speed: 3.3ms preprocess, 208.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 206.1ms
# Speed: 3.3ms preprocess, 206.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 212.8ms
# Speed: 3.3ms preprocess, 212.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 185.7ms
# Speed: 2.9ms preprocess, 185.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 8 cars, 1 bus, 199.0ms
# Speed: 5.0ms preprocess, 199.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 320x640 2 persons, 9 cars, 1 bus, 161.8ms
# Speed: 2.9ms preprocess, 161.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=21, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 320x640 3 persons, 9 cars, 1 bus, 129.9ms
# Speed: 3.2ms preprocess, 129.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=24, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 1}}, total_tracks=13)
#
# 0: 320x640 3 persons, 9 cars, 1 bus, 142.0ms
# Speed: 3.7ms preprocess, 142.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=25, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 1, 'OUT': 1}}, total_tracks=13)
#
# 0: 320x640 4 persons, 9 cars, 1 bus, 143.1ms
# Speed: 3.1ms preprocess, 143.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 4 persons, 9 cars, 1 bus, 154.6ms
# Speed: 5.4ms preprocess, 154.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 3 persons, 9 cars, 1 bus, 171.2ms
# Speed: 3.5ms preprocess, 171.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=13)
#
# 0: 320x640 4 persons, 9 cars, 1 bus, 185.3ms
# Speed: 4.8ms preprocess, 185.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 4 persons, 9 cars, 1 bus, 227.4ms
# Speed: 3.7ms preprocess, 227.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 3 persons, 9 cars, 1 bus, 224.1ms
# Speed: 3.2ms preprocess, 224.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=13)
#
# 0: 320x640 4 persons, 9 cars, 1 bus, 218.0ms
# Speed: 3.7ms preprocess, 218.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 4 persons, 10 cars, 1 bus, 208.0ms
# Speed: 3.4ms preprocess, 208.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=15)
#
# 0: 320x640 4 persons, 10 cars, 1 bus, 215.4ms
# Speed: 3.6ms preprocess, 215.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=15)
#
# 0: 320x640 3 persons, 10 cars, 1 bus, 151.6ms
# Speed: 3.8ms preprocess, 151.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
#
# 0: 320x640 3 persons, 10 cars, 1 bus, 150.1ms
# Speed: 3.8ms preprocess, 150.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 🚀 Results: SolutionResults(in_count=26, out_count=22, classwise_count={'car': {'IN': 20, 'OUT': 21}, 'truck': {'IN': 4, 'OUT': 0}, 'bus': {'IN': 0, 'OUT': 0}, 'person': {'IN': 2, 'OUT': 1}}, total_tracks=14)
# Video frame is empty or processing is complete.
